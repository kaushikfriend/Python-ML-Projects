# %% [markdown]
# <h1>TABLE OF CONTENTS<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Model-Prediction-of-Stock-Price---By:-Kaushik-Rathod" data-toc-modified-id="Model-Prediction-of-Stock-Price---By:-Kaushik-Rathod-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Model Prediction of Stock Price   By: Kaushik Rathod</a></span><ul class="toc-item"><li><span><a href="#Problem-Statment" data-toc-modified-id="Problem-Statment-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Problem Statment</a></span><ul class="toc-item"><li><span><a href="#Predict-stock-price-based-on-given-data" data-toc-modified-id="Predict-stock-price-based-on-given-data-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Predict stock price based on given data</a></span></li><li><span><a href="#Use-a-different-types-of-model-and-predict" data-toc-modified-id="Use-a-different-types-of-model-and-predict-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Use a different types of model and predict</a></span></li></ul></li></ul></li><li><span><a href="#Import-Library" data-toc-modified-id="Import-Library-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import Library</a></span></li><li><span><a href="#Dataset-details" data-toc-modified-id="Dataset-details-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Dataset details</a></span><ul class="toc-item"><li><span><a href="#Feature-&amp;-Details-of-the-Dataset" data-toc-modified-id="Feature-&amp;-Details-of-the-Dataset-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Feature &amp; Details of the Dataset</a></span><ul class="toc-item"><li><span><a href="#There-are-multiple-variables-in-the-dataset-date,-open,-high,-low,-last,-close,-quantity,-and-turnover." data-toc-modified-id="There-are-multiple-variables-in-the-dataset-date,-open,-high,-low,-last,-close,-quantity,-and-turnover.-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>There are multiple variables in the dataset date, open, high, low, last, close, quantity, and turnover.</a></span></li></ul></li></ul></li><li><span><a href="#EDA-on-Data" data-toc-modified-id="EDA-on-Data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>EDA on Data</a></span><ul class="toc-item"><li><span><a href="#Profiling-Data-before-Data-Preprocessing" data-toc-modified-id="Profiling-Data-before-Data-Preprocessing-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Profiling Data before Data Preprocessing</a></span></li><li><span><a href="#Data-Pre-Processing-Overview" data-toc-modified-id="Data-Pre-Processing-Overview-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Data Pre Processing Overview</a></span><ul class="toc-item"><li><span><a href="#Make-a-copy-of-original-data-and-use-new-for-future" data-toc-modified-id="Make-a-copy-of-original-data-and-use-new-for-future-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Make a copy of original data and use new for future</a></span></li><li><span><a href="#Dropping-Null-valube-data" data-toc-modified-id="Dropping-Null-valube-data-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Dropping Null valube data</a></span></li><li><span><a href="#Changing-Date-Data-type,-string-to-Datetime-and-Setting-Date-as-Index" data-toc-modified-id="Changing-Date-Data-type,-string-to-Datetime-and-Setting-Date-as-Index-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Changing Date Data type, string to Datetime and Setting Date as Index</a></span></li><li><span><a href="#Ploting-Closing-stock-price-to-check-overall-performance" data-toc-modified-id="Ploting-Closing-stock-price-to-check-overall-performance-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Ploting Closing stock price to check overall performance</a></span></li><li><span><a href="#Box-Plot-to-check-outlier" data-toc-modified-id="Box-Plot-to-check-outlier-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Box Plot to check outlier</a></span></li></ul></li></ul></li><li><span><a href="#Train---Test-Data" data-toc-modified-id="Train---Test-Data-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Train - Test Data</a></span></li><li><span><a href="#Prediction-using-Model" data-toc-modified-id="Prediction-using-Model-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Prediction using Model</a></span><ul class="toc-item"><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Linear Regression</a></span></li><li><span><a href="#ARIMA" data-toc-modified-id="ARIMA-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>ARIMA</a></span></li><li><span><a href="#TIME-SERIES" data-toc-modified-id="TIME-SERIES-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>TIME SERIES</a></span><ul class="toc-item"><li><span><a href="#Define-Functions" data-toc-modified-id="Define-Functions-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Define Functions</a></span></li></ul></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# <img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="240" height="360" />
#
# # Model Prediction of Stock Price   By: Kaushik Rathod

# %% [markdown]
# ## Problem Statment
#
#   - ### Predict stock price based on given data
#   - ### Use a different types of model and predict
#
# ![StockPrice.jpg](attachment:StockPrice.jpg)

# %% [markdown]
# # Import Library

# %%
# Import libraries 
import numpy as np                    
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
from datetime import datetime

# Numpy Setting 
np.set_printoptions(precision=4)     #To set values upto Four decimal places.

# Pandas Setting
pd.set_option('mode.chained_assignment', None)      # To Hide pandas warnings

# Matplotlib Setting
plt.style.use('seaborn-whitegrid')    # To apply seaborn whitegrid style to the plots.
plt.rc('figure', figsize=(10, 8))     # Set the default figure size of plots.
# %matplotlib inline

# Warnings Setting
warnings.filterwarnings("ignore")     # To suppress all the warnings in the notebook.



#setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,12

#sklearn for normalizing data
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

scaler = MinMaxScaler(feature_range=(0, 1))

# ARIMA Model
from statsmodels.tsa.arima_model import ARIMA

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

import plotly.graph_objs as go

# %% [markdown]
# # Dataset details
# - Taken Dataset from NSE-TATAGLOBAL from the Internet to evaluate one stock price with using various models and predict future price
#
# http://localhost:8888/edit/PythonCodes/PROJECT/ML2/STOCKPRICE.csv

# %% [markdown]
# ## Feature & Details of the Dataset
#
# | Column Name                     | Description                                                                               |
# |:------------------------------- |:------------------------------------------------------------------------------------------|
# | Date                            | Date of Stock                                                                             |
# | Open                            | Opening price of the share for the day                                                    |
# | High                            | Highest price of the share for the day                                                    |
# | Low                             | Lowest price of the share for the day                                                     |
# | Last                            | Last price of the share for the day                                                       |
# | Close                           | Final price of the share for the day                                                      |
# | Quantity                        | Trade total quantity for the day                                                          |
# | Turnover                        | Turnover for the day in lacs                                                              |
# |---------------------------------|-------------------------------------------------------------------------------------------|
#
#
# ### There are multiple variables in the dataset date, open, high, low, last, close, quantity, and turnover.
#
# - The columns Open and Close represent the starting and final price at which the stock is traded on a particular day.
#
# - High, Low and Last represent the maximum, minimum, and last price of the share for the day.
#
# - Quantity is the number of total shares bought or sold in the day and Turnover (in Lacs) is the turnover of the particular company on a given date.
#
# Another important thing to note is that the market is closed on weekends and public holidays.Notice the above table again, some date values are missing.
#
# The profit or loss calculation is usually determined by the closing price of a stock for the day, hence we will consider the closing price as the target variable. Let’s plot the target variable to understand how it’s shaping up in our data:

# %%
sfilename = "STOCKPRICE"
print("Processing for Dataset :", sfilename)
data = pd.read_csv(sfilename + '.csv')
# Out:
# Processing for Dataset : STOCKPRICE

# %% [markdown]
# # EDA on Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1235 non-null   object
#  1   Open      1235 non-null   float64
#  2   High      1235 non-null   float64
#  3   Low       1235 non-null   float64
#  4   Last      1235 non-null   float64
#  5   Close     1235 non-null   float64
#  6   Quantity  1235 non-null   int64
#  7   Turnover  1235 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 77.3+ KB

# %%
data.shape
# Out:
# (1235, 8)

# %%
data.head()
# Out:
#          Date    Open    High     Low   Last   Close  Quantity  Turnover
# 0  08-09-2015  157.00  157.80  155.20  155.8  155.80   1720413   2688.94
# 1  09-09-2015  155.70  158.20  154.15  155.3  155.55   2049580   3204.49
# 2  10-09-2015  156.00  160.80  155.85  160.3  160.15   3124853   4978.80
# 3  11-09-2015  161.15  163.45  159.00  159.8  160.05   1880046   3030.76
# 4  14-09-2015  160.85  161.45  157.70  159.3  159.45   1281419   2039.09

# %% [markdown]
# ## Profiling Data before Data Preprocessing

# %%
profile = data.profile_report(title='Pandas Profiling before Data Preprocessing')
profile.to_file(output_file="Preprocessing_"+ sfilename +".html")

# %% [markdown]
# ## Data Pre Processing Overview
# __Dataset analysis__
#
# - Number of variables: 8
# - Number of observations: 1235
# - Missing cells (%): 0%
# - Duplicate rows (%): 0.0%
#
# __Data Types__
#
# - Numeric = 7
# - Categorical = 1
#
#
# __Other Analysis__
#
# - **Date** is type of string, convert to datetime
#
# - **Most of the Data** are **highly** correlated.

# %% [markdown]
# ### Make a copy of original data and use new for future

# %%
if data.Date.dtype == object:
    data["Date"] = data.Date.apply(lambda x: datetime.strptime(x,"%d-%m-%Y"))

# %%
data = data.sort_values(by=['Date'])

# %%
data.head()
# Out:
#         Date    Open    High     Low   Last   Close  Quantity  Turnover
# 0 2015-09-08  157.00  157.80  155.20  155.8  155.80   1720413   2688.94
# 1 2015-09-09  155.70  158.20  154.15  155.3  155.55   2049580   3204.49
# 2 2015-09-10  156.00  160.80  155.85  160.3  160.15   3124853   4978.80
# 3 2015-09-11  161.15  163.45  159.00  159.8  160.05   1880046   3030.76
# 4 2015-09-14  160.85  161.45  157.70  159.3  159.45   1281419   2039.09

# %%
data.tail()
# Out:
#            Date    Open    High     Low    Last   Close  Quantity  Turnover
# 1230 2020-08-31  234.55  234.60  221.05  230.30  230.90   1534749   3486.05
# 1231 2020-09-02  230.00  237.50  225.75  226.45  227.60   1708590   3960.27
# 1232 2020-09-03  223.50  227.80  216.15  217.25  218.20   1728786   3815.79
# 1233 2020-09-04  217.00  218.60  205.90  210.25  209.20   3519515   7407.06
# 1234 2020-09-05  208.00  222.25  206.85  216.00  215.15   4642146  10062.83

# %%
data_new = data.copy(deep=True)   #make a copy of original data
data_new.head()
# Out:
#         Date    Open    High     Low   Last   Close  Quantity  Turnover
# 0 2015-09-08  157.00  157.80  155.20  155.8  155.80   1720413   2688.94
# 1 2015-09-09  155.70  158.20  154.15  155.3  155.55   2049580   3204.49
# 2 2015-09-10  156.00  160.80  155.85  160.3  160.15   3124853   4978.80
# 3 2015-09-11  161.15  163.45  159.00  159.8  160.05   1880046   3030.76
# 4 2015-09-14  160.85  161.45  157.70  159.3  159.45   1281419   2039.09

# %% [markdown]
# ###  Dropping Null valube data

# %%
data_new.dropna(inplace=True)          ##Dropping rows with null values
data_new.reset_index(drop=True,inplace=True)
data_new.shape
# Out:
# (1235, 8)

# %%
data_new.isnull().sum()
# Out:
# Date        0
# Open        0
# High        0
# Low         0
# Last        0
# Close       0
# Quantity    0
# Turnover    0
# dtype: int64

# %% [markdown]
# ###  Changing Date Data type, string to Datetime and Setting Date as Index

# %%
if data_new.Date.dtype == object:
    data_new["Date"] = data_new.Date.apply(lambda x: datetime.strptime(x,"%d-%m-%Y"))

# %%
#setting index as date
data_new.index = data_new['Date']

# %%
# data_new.head()
data_new.tail()
# Out:
#                  Date    Open    High     Low    Last   Close  Quantity  \
# Date
# 2020-08-31 2020-08-31  234.55  234.60  221.05  230.30  230.90   1534749
# 2020-09-02 2020-09-02  230.00  237.50  225.75  226.45  227.60   1708590
# 2020-09-03 2020-09-03  223.50  227.80  216.15  217.25  218.20   1728786
# 2020-09-04 2020-09-04  217.00  218.60  205.90  210.25  209.20   3519515
# 2020-09-05 2020-09-05  208.00  222.25  206.85  216.00  215.15   4642146
#
#             Turnover
# Date
# 2020-08-31   3486.05
# 2020-09-02   3960.27
# 2020-09-03   3815.79
# 2020-09-04   7407.06
# 2020-09-05  10062.83

# %% [markdown]
# ### Ploting Closing stock price to check overall performance

# %%
plt.rcParams['axes.facecolor'] = 'w'
data_new['Quantity'].plot(label ="Quantity", figsize=(16,8))
plt.title('Volume Trading',fontsize =20, pad = 20);
plt.xlabel('Years', fontsize =20);
plt.legend( prop={'size': 20});
plt.savefig('VolumeTrading.png')

# %%
rcParams['figure.figsize'] = 20,12
from pandas.plotting import lag_plot
lag_plot(data_new['Open'], lag=3)
plt.title('Stock - Autocorrelation plot with lag = 3', fontsize=20, pad = 10)
plt.show();
plt.savefig('StockAutoCorr.png')

# %%
plt.plot(data_new['Close'], label= 'Closing Price');
plt.ylabel('Price',fontsize=20,fontweight="bold")
plt.xlabel('Years',fontsize=20,fontweight="bold")
plt.title("Stock price over time",fontsize=20,pad =10, fontweight="bold")
plt.legend( prop={'size': 20 });
plt.savefig('Stockprice.png')

# %% [markdown]
# ### Box Plot to check outlier

# %%
# BoxPlot(['Open','High','Low','Close', 'Last'],'','','',False)
data_new[['Open','High','Low','Close', 'Last']].plot(kind='box')
plt.savefig('BoxPlot.png')

# %%
days = (data_new['Date'].max() - data_new['Date'].min()).days
print('Minimum Date:',data_new['Date'].min(), ' Maximum Date:',data_new['Date'].max(),'Total Number of Days:',days)
# Out:
# Minimum Date: 2015-09-08 00:00:00  Maximum Date: 2020-09-05 00:00:00 Total Number of Days: 1824

# %%
dYear = data_new.groupby(data_new['Date'].dt.year)['Quantity'].sum().sort_values(ascending=False)
print('\n')
dYear.plot(kind='pie',legend=True, fontsize=20, autopct='%3.1f%%',colormap = 'summer', 
        shadow=True,startangle=163)
plt.xlabel('Years',fontsize=40)
plt.ylabel('',fontsize=40)
plt.title('Quantity Trading - Year wise Distribution',fontsize=35,pad = 10);
plt.legend( prop={'size': 20});
plt.savefig('Yearwise.png')

# %%
dMonth = data_new.groupby(data_new['Date'].dt.month)['Quantity'].sum().sort_values(ascending=False)
print('\n')
dMonth.plot(kind='pie',legend=True, fontsize=20, autopct='%3.1f%%',colormap = 'vlag', 
        shadow=True)
plt.xlabel('Months',fontsize=30)
plt.ylabel('',fontsize=40)
plt.title('Quantity Trading - Month wise Distribution',fontsize=35,pad = 40);
plt.legend( loc='best',prop={'size': 12});
plt.savefig('Monthwise1.png')

# %%
print('\n')
dMonth.plot(kind='pie', autopct='%3.1f%%', wedgeprops=dict(width=0.2),
                                shadow=True,startangle=140, legend=True, figsize=(12,10), cmap='Set3')
plt.xlabel('',fontsize=30)
plt.ylabel('',fontsize=40)
plt.title('Quantity Trading - Month wise Distribution',fontsize=35,pad = 40);
plt.legend(loc='best',prop={'size': 12});
plt.savefig('Monthwise2.png')

# %%
# Plotting the correlation matrix
corr_mat = data_new.corr()
sns.heatmap(corr_mat, annot=True, cmap='brg')
plt.title('Correlation Matrix' , fontsize=35,pad = 40)
plt.savefig('Correlation.png')

# %% [markdown]
# **Observations from Correlation Matrix** <br>
# - The **diagonal** of above matrix shows the **auto-correlation** of variable. It is always equal to 1.
#
#
# - **Correlations** can vary from **-1 to +1**. Closer to **+1 means strong positive correlation** and close **-1 means strong negative correlation**. Closer to **0 means not very strongly correlated**. Variables with strong correlations are mostly probable candidates for model builing.
#
# - There is no **negative correlation** in the dataset. In fact data are highly correlated.
#
# - As we can see turnover is high, once quantity trading is also high.

# %%
# # Using seaborn's pairplot function to plot the pairplot for specific columns of the dataset.
sns.set(style='whitegrid', font_scale=1.3, color_codes=True)      # To adjust seaborn settings for the plots.

sns.pairplot(data=data_new[['Open', 'Close','High','Low','Last','Turnover','Quantity']], 
             size=2.5, diag_kind='kde');
plt.savefig('pairplot.png');

# %% [markdown]
# # Train - Test Data

# %%
model_data = data_new.sort_index(ascending=True, axis=0)
model_data.head()
# Out:
#                  Date    Open    High     Low   Last   Close  Quantity  \
# Date
# 2015-09-08 2015-09-08  157.00  157.80  155.20  155.8  155.80   1720413
# 2015-09-09 2015-09-09  155.70  158.20  154.15  155.3  155.55   2049580
# 2015-09-10 2015-09-10  156.00  160.80  155.85  160.3  160.15   3124853
# 2015-09-11 2015-09-11  161.15  163.45  159.00  159.8  160.05   1880046
# 2015-09-14 2015-09-14  160.85  161.45  157.70  159.3  159.45   1281419
#
#             Turnover
# Date
# 2015-09-08   2688.94
# 2015-09-09   3204.49
# 2015-09-10   4978.80
# 2015-09-11   3030.76
# 2015-09-14   2039.09

# %%
# Splitting the dataset into training and test sets.
X= np.array(data.index).reshape(-1,1)
Y= data['Close']
X_train, X_test,Y_train, Y_Test = train_test_split(X,Y, test_size = 0.3, random_state = 101)

# %%
#Feature Scaling
scaler = StandardScaler().fit(X_train)

# %% [markdown]
# # Prediction using Model

# %% [markdown]
# ## Linear Regression

# %%
# Creating our linear regression model and fitting the data into it.
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot
init_notebook_mode(connected=True)

layout=go.Layout(
        title=go.layout.Title(text="Linear Model Price Prediction") )
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
trace0= go.Scatter(
    x = X_train.T[0],
    y = Y_train,
    mode = 'markers',
    name = 'Actual'
)
trace1= go.Scatter(
    x = X_train.T[0],
    y = linreg.predict(X_train).T,
    mode = 'lines',
    name = 'Predicted'
)
trace_data = [trace0,trace1]
layout.xaxis.title.text = 'Day'
plot2 = go.Figure(data = trace_data, layout = layout)

# %%
iplot(plot2)
# Out:
# <div>                            <div id="031d23cf-506e-4b30-bb8e-2516efd22748" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("031d23cf-506e-4b30-bb8e-2516efd22748")) {                    Plotly.newPlot(                        "031d23cf-506e-4b30-bb8e-2516efd22748",                        [{"mode": "markers", "name": "Actual", "type": "scatter", "x": [298, 62, 420, 798, 805, 231, 749, 1102, 483, 98, 63, 621, 1119, 1201, 818, 985, 1091, 1150, 835, 976, 528, 814, 943, 789, 1168, 776, 1139, 761, 225, 346, 106, 779, 9, 180, 1018, 306, 752, 975, 878, 722, 171, 941, 204, 1019, 1108, 952, 607, 417, 866, 946, 755, 495, 992, 8, 613, 719, 882, 366, 334, 1104, 240, 1140, 1093, 216, 1169, 845, 670, 23, 1218, 1096, 123, 725, 142, 1026, 610, 1003, 108, 439, 820,
# ...

# %%
score = f''' 
{'Metric'.ljust(10)} {'Train'.center(20)} {'Test'.center(20)}
{'R2 Score'.ljust(10)}{r2_score(Y_train,linreg.predict(X_train))}\t {r2_score(Y_Test,linreg.predict(X_test))} 
{'MSE'.ljust(10)}{mse(Y_train,linreg.predict(X_train))}\t {mse(Y_Test,linreg.predict(X_test))} 
'''

# %%
print(score)
# Out:
#
# Metric            Train                 Test
# R2 Score  0.3910202219835317	 0.3359356351526971
# MSE       1623.4990810094944	 1739.8993288418003

# %% [markdown]
# ## ARIMA

# %%
# Splitting the dataset into training and test sets.
# train_data, test_data = train_test_split(model_data, test_size = 0.2, random_state = 2)

train_data, test_data = model_data[0:int(len(model_data)*0.7)], model_data[int(len(model_data)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mse(test_data, model_predictions)
print('Testing Mean Squared Error is {}'.format(MSE_error))
# Out:
# Testing Mean Squared Error is 27.70484251331844

# %%
test_set_range = model_data[int(len(model_data)*0.7):].index
plt.figure(figsize=(16,10))
plt.plot(test_set_range, model_predictions, color='blue', marker='o', linestyle='dashed',
         label='Predicted Price')
plt.plot(test_set_range, test_data, color='red', label='Actual Price')
plt.title('ARIMA Prices Prediction', fontsize = 20, pad = 10)
plt.xlabel('Date',fontsize = 20)
plt.ylabel('Prices',fontsize = 20)
# plt.xticks(np.arange(0,1600,10), model_data.Date[0:1600:10])
plt.legend(prop={'size': 20});
plt.show();
plt.savefig('ARIMAPricePrediction.png');

# %% [markdown]
# ## TIME SERIES

# %%
df_close = model_data['Close']
df_close.plot(style='k.')
plt.title('Scatter plot of closing price', fontsize = 20, pad = 10)
plt.xlabel('Date',fontsize = 20)
plt.show()
plt.savefig('Time Series Scatter Plot.png');

# %% [markdown]
# ### Define Functions

# %%
def rolling_means(timeSeries_column_name):
    rolmean  =  timeSeries_column_name.rolling(window = 12).mean()    #window size 12 denotes 12 months, giving rolling mean at yearly level
    rolstd  =  timeSeries_column_name.rolling(window = 12).std()

    timeSeries_column_name.plot( color = 'blue', label = 'Original')
    rolmean.plot(color = 'red', label = 'Rolling Mean')
    std  =  rolstd.plot(color = 'black', label = 'Rolling Std')
    plt.legend(loc = 'best',prop={'size': 20})
    plt.title('Rolling Mean & Standard Deviation', fontsize = 20, pad =10)
    plt.xlabel('Years', fontsize = 20)
    plt.show(block = False)
    plt.savefig('Rolling-Mean-STD.png');

#Perform Augmented Dickey–Fuller test:
def adf_test(timeSeries_column_name):
    from statsmodels.tsa.stattools import adfuller
    dftest  =  adfuller(timeSeries_column_name, autolag = 'AIC')

    dfoutput  =  pd.Series(dftest[0:4], index = ['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key]  =  value
    
    print('Results of Dickey Fuller Test:')    
    print(dfoutput)
    
#Test for staionarity
def test_stationarity(timeSeries_columnName):
    rolling_means(timeSeries_columnName)
    adf_test(timeSeries_columnName)

# %%
test_stationarity(df_close)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                   -0.954896
# p-value                           0.769358
# #Lags Used                       16.000000
# Number of Observations Used    1218.000000
# Critical Value (1%)              -3.435730
# Critical Value (5%)              -2.863916
# Critical Value (10%)             -2.568035
# dtype: float64

# %%
df_Temp = model_data
def generate():
    df_Temp['Close'] = np.log(df_Temp.Close)
    df_Temp.Close.plot()
    plt.title('Closing Price based on log', fontsize = 20, pad =10)
    plt.xlabel('Years', fontsize = 20)
    plt.savefig('LogClosingPrice.png');
    return df_Temp
df_Temp = generate()
df_Temp.head()
# Out:
#                  Date    Open    High     Low   Last     Close  Quantity  \
# Date
# 2015-09-08 2015-09-08  157.00  157.80  155.20  155.8  5.048573   1720413
# 2015-09-09 2015-09-09  155.70  158.20  154.15  155.3  5.046967   2049580
# 2015-09-10 2015-09-10  156.00  160.80  155.85  160.3  5.076111   3124853
# 2015-09-11 2015-09-11  161.15  163.45  159.00  159.8  5.075486   1880046
# 2015-09-14 2015-09-14  160.85  161.45  157.70  159.3  5.071730   1281419
#
#             Turnover
# Date
# 2015-09-08   2688.94
# 2015-09-09   3204.49
# 2015-09-10   4978.80
# 2015-09-11   3030.76
# 2015-09-14   2039.09

# %%
result = seasonal_decompose(df_close, model='multiplicative', freq = 30);
fig = plt.figure(); 
fig = result.plot();
plt.savefig('LogClosingPrice_Decompose.png');

# %%
df_log = np.log(df_close)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
# plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.show();
plt.savefig('MovingAverage.png');

# %%
#split data into train and training set
train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices', fontsize = 20)
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend();
plt.savefig('TrainTestData.png');

# %% [markdown]
# # Conclusion
#
# - <b>The dataset taken of NSE-TATAGLOBAL from internet.<b>The historical data from the year 2015 to 2020 were taken in to account for analysis.</b>
# - Used Linear Regression, ARIMA and Time Series to trained and predicted the stock prices on the test dataset.
# - ARIMA doing good among all 3 model
